# %% [markdown]
# 1. 키보드로 부터 수를 입력받아 짝수인지 홀수인지 판별하는 함수를 만드세요.

# %%
def check_even(num):
    num = int(input("숫자를 입력해주세요:> "))
    # val = num % 2 != 0
    if num % 2 == 0:
        print("입력된 값:", num)
        print("짝수입니다.")
    else:
        print("입력된 값:", num)
        print("홀수입니다.")

    #여기에 코드를 입력하세요 (홀짝 판별)



#실행
check_even(0) # 출력 - 12 : 짝수입니다
# check_even(12) # 출력 - 12 : 짝수입니다
# num = int(input("숫자를 입력해 주세요:> "))
#여기에 코드를 입력하세요 (키보드로 부터 수 입력 받기)
# check_even(val) # 출력 - 7 : 홀수입니다
# Out:
# 입력된 값: 9
# 홀수입니다.

# %% [markdown]
# 2. 리스트에서 양수(0보다 큰 수)만 출력하는 함수를 만드세요.

# %%
def check_positive(numbers):
    #여기에 코드를 입력하세요
    numbers = [-3, 0, 5, 8, -1]
    
    for x in numbers:
        numbers > 0
    print(numbers)
    

#실행
# check_positive([-3, 0, 5, 8, -1]) # 출력 : 5 8

# %% [markdown]
# 3. 점수에 따라 학점을 출력하는 함수를 만드세요.

# %%
def grade(score):
    #여기에 코드를 입력하세요
    score =  int(input("점수를 입력하세요:> "))

    if 90 <= score <=100:
        print(f"{score}점 :A 입니다")
    elif 80 <= score < 90:
        print(f"{score}점 : B 입니다")
    elif 70 <= score < 80:
        print(f"{score}점 : C 입니다")
    elif 60 <= score < 70:
        print(f"{score}점 : D 입니다")
    elif 0 <= score < 60:
        print(f"{score}점 : F 입니다")
    else:
        print("잘못된 점수입니다.")

grade("")
#실행
# grade(85) #출력 - 85점 : B 입니다
# grade(43) #출력 - 43점 : F 입니다
# Out:
# 20점 : F 입니다

# %% [markdown]
# 4. 리스트에서 최대값을 계산하는 함수를 만드세요.

# %%
def find_max(numbers):
    v = find_max([3, 9, 1, 12, 4])
    for x in v:
        if x < max :
            print(numbers)

#실행
print("모르겠어요 ㅠㅠ..") #출력 - Max : 12
# print("#여기에 코드를 입력하세요" ) #출력 - Max : 12
# Out:
# <built-in function max>

# %% [markdown]
# 5. 기준 점수 이상의 학생 이름을 출력하는 함수를 작성하세요.

# %%
scores = {
    "영희" : 85,
    "철수" : 92,
    "민수" : 78,
    "지우" : 90
}



def get_score(name):
    for name in scores:
        scores_dict
    
    

def filter_students(scores_dict, threshold):
    #여기에 코드를 입력하세요
    # scores_dict = scores.items
    # threshold = range(len(scores_dict))
    # for i in scores_dict :
    #     print(threshold ,scores_dict[i])
    # if scores.values >= 90:
    #     print(scores_dict)
    pass

scores_dict = scores.items()

#실행
# print(get_score("영희")) #출력 :85
# print(get_score("준호")) #출력 : 찾을 수 없습니다
print(filter_students(scores,90)) #출력 : ['철수', '지우']
# Out:
# <built-in method items of dict object at 0x000001D3AFDC0A80>
# None

# %% [markdown]
# 6. 문자열을 콤마(,)로 분리하여 리스트에 저장하고,
# 1번부터 번호를 매겨 이름과 함께 출력하는 프로그램을 작성하세요.

# %%
names = "영희,철수,민수,지우"
#여기에 코드를 입력하세요 (문자열을 리스트로 변환하여 저장)
a = names.split(",")
print(a)

#여기에 코드를 입력하세요 (번호, 이름 함께 출력하기)
for i in range(len(a)) :
  print(i, a[i])
# Out:
# ['영희', '철수', '민수', '지우']
# 0 영희
# 1 철수
# 2 민수
# 3 지우
